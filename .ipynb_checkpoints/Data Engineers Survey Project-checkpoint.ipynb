# %% [markdown]
# # Import Lib & Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Data_engineers_Survey_results.csv') #read dataset

# %% [markdown]
# # Data EXPLORATION

# %%
df.shape
# Out:
# (600, 46)

# %%
df.size
# Out:
# 27600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 46 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   GENDER      600 non-null    object
#  1   AGE         600 non-null    int64
#  2   EMPLOYMENT  600 non-null    object
#  3   STATE       600 non-null    object
#  4   REGION      600 non-null    object
#  5   EDUCATION   600 non-null    object
#  6   QA_M1       600 non-null    object
#  7   QA_M2       600 non-null    object
#  8   QA_M3       600 non-null    object
#  9   QA_M4       549 non-null    object
#  10  QA_M5       400 non-null    object
#  11  QA_M6       168 non-null    object
#  12  QA_M7       34 non-null     object
#  13  QA_M8       7 non-null      object
#  14  QB          600 non-null    object
#  15  QC          600 non-null    object
#  16  QD          600 non-null    object
#  17  Q1          600 non-null    object
#  18  Q2          600 non-null    object
#  19  Q3          600 non-null    int64
#  20  Q4          600 non-null    int64
#  21  Q5_M1       600 non-null    object
#  22  Q5_M2       571 non-null    object
#  23  Q5_M3       454 non-null    object
#  24  Q5_M4       96 non-null     object
#  25  Q5_M5       9 non-null      object
#  26  Q6          600 non-null    object
#  27  Q7          600 non-null    object
#  28  Q8          600 non-null    object
#  29  Q9          600 non-null    object
#  30  Q10         600 non-null    object
#  31  Q11         600 non-null    object
#  32  Q12         600 non-null    object
#  33  Q13         600 non-null    object
#  34  Q14_M1      361 non-null    object
#  35  Q14_M2      353 non-null    object
#  36  Q14_M3      318 non-null    object
#  37  Q14_M4      111 non-null    object
#  38  Q14_M5      18 non-null     object
#  39  Q15         600 non-null    object
#  40  QE          600 non-null    object
#  41  QF          600 non-null    object
#  42  QG          600 non-null    object
#  43  QH          600 non-null    int64
#  44  QI          600 non-null    object
#  45  QJ          600 non-null    object
# dtypes: int64(4), object(42)
# memory usage: 215.8+ KB

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#   GENDER  AGE         EMPLOYMENT      STATE   REGION  \
# 0   Male   39  \tWork full-time   Wisconsin  Midwest
# 1   Male   39  \tWork full-time     Florida    South
# 2   Male   34  \tWork full-time     Florida    South
# 3   Male   38  \tWork full-time   Wisconsin  Midwest
# 4   Male   39  \tWork full-time     Georgia    South
#
#                           EDUCATION  \
# 0  \tGraduate or post-graduate work
# 1               \tBachelor’s degree
# 2  \tGraduate or post-graduate work
# 3  \tGraduate or post-graduate work
# 4  \tGraduate or post-graduate work
#
#                                                QA_M1  \
# 0  Maintain the distributed systems that execute ...
# 1  Develop, maintain, and optimize data systems t...
# 2                              Create data pipelines
# 3  Maintain the distributed systems that execute ...
# 4  Manage continuous integration and continuous d...
#
#                                                QA_M2  \
# 0  Develop, maintain, and optimize data systems t...
# 1  Maintain the distributed systems that execute ...
# 2  Develop, maintain, and optimize data systems t...
# 3              Maintain data in ready-to-use formats
# 4  Maintain the distributed systems that execute ...
#
#                                                QA_M3  \
# 0  Ensure that the data architecture will scale a...
# 1                                Write and test code
# 2  Write tests to ensure that bad data is detecte...
# 3  Manage continuous integration and continuous d...
# 4              Maintain data in ready-to-use formats
#
#                                                QA_M4  \
# 0                                Write and test code
# 1  Manage continuous integration and continuous d...
# 2  Maintain the distributed systems that execute ...
# 3                                                NaN
# 4  Develop, maintain, and optimize data systems t...
#
#                                                QA_M5  \
# 0  Manage continuous integration and continuous d...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Ensure that the data architecture will scale a...
#
#                            QA_M6  \
# 0  Put analytics into production
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#                                                QA_M7  \
# 0  Write tests to ensure that bad data is detecte...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                    QA_M8                         QB   QC  \
# 0  Maintain data in ready-to-use formats              ETL Developer  Yes
# 1                                    NaN       Enterprise Architect  Yes
# 2                                    NaN      Data & Analytics Lead  Yes
# 3                                    NaN  Enterprise Analytics Lead  Yes
# 4                                    NaN      Data & Analytics Lead  Yes
#
#                                                   QD  \
# 0  We have partially implemented DataOps into our...
# 1  We have partially implemented DataOps into our...
# 2  We have mostly or fully implemented DataOps in...
# 3  We have mostly or fully implemented DataOps in...
# 4  We have mostly or fully implemented DataOps in...
#
#                                                   Q1            Q2  Q3  Q4  \
# 0  We frequently hope and pray that things don’t ...         Often   1   1
# 1                  We are confident they won’t break     Sometimes  20  10
# 2  We frequently hope and pray that things don’t ...  All the time  25   5
# 3                  We are confident they won’t break  All the time  70  60
# 4                  We are confident they won’t break         Often  40  35
#
#                                                Q5_M1  \
# 0  Focusing too much on maintaining data pipeline...
# 1  Constantly playing catch up with stakeholder r...
# 2  Focusing too much time on finding and fixing e...
# 3            Fast pace of requests from stakeholders
# 4  Focusing too much on maintaining data pipeline...
#
#                                                Q5_M2  \
# 0                                                NaN
# 1                                                NaN
# 2            Unreasonable requests from stakeholders
# 3  Constantly playing catch up with stakeholder r...
# 4            Fast pace of requests from stakeholders
#
#                                                Q5_M3 Q5_M4 Q5_M5  \
# 0                                                NaN   NaN   NaN
# 1                                                NaN   NaN   NaN
# 2                                                NaN   NaN   NaN
# 3                                                NaN   NaN   NaN
# 4  Focusing too much time on finding and fixing e...   NaN   NaN
#
#                Q6            Q7            Q8                 Q9  \
# 0  Agree somewhat         Often         Often        Very likely
# 1  Agree strongly  All the time        Rarely        Very likely
# 2  Agree strongly     Sometimes  All the time    Not very likely
# 3  Agree strongly  All the time         Often  Not at all likely
# 4  Agree somewhat     Sometimes     Sometimes    Not very likely
#
#                    Q10                 Q11                   Q12  \
# 0  Yes, multiple times  Somewhat difficult  Somewhat effectively
# 1  Yes, multiple times  Somewhat difficult      Very effectively
# 2  Yes, multiple times  Somewhat difficult      Very effectively
# 3  Yes, multiple times      Very difficult      Very effectively
# 4            Yes, once  Somewhat difficult  Somewhat effectively
#
#               Q13                                         Q14_M1  \
# 0  Very important       Lack of knowledge around what DataOps is
# 1  Very important  Organization isn’t sure how to implement this
# 2       Essential                                            NaN
# 3       Essential                                            NaN
# 4  Very important                                            NaN
#
#                                               Q14_M2  \
# 0                                                NaN
# 1  Lack of buy-in from company leadership or othe...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      Q14_M3 Q14_M4 Q14_M5             Q15  QE  \
# 0                                       NaN    NaN    NaN  Agree somewhat  10
# 1  Lack of knowledge around what DataOps is    NaN    NaN  Agree somewhat   5
# 2                                       NaN    NaN    NaN  Agree strongly  10
# 3                                       NaN    NaN    NaN  Agree strongly  18
# 4                                       NaN    NaN    NaN  Agree somewhat   6
#
#    QF  QG    QH                                  QI  \
# 0  10  11  1500   $50 Million to under $100 Million
# 1  10  50  2000    $10 Million to under $25 Million
# 2  15  20    20                  $1 Billion or more
# 3  18  45   250  $100 Million to under $250 Million
# 4   7  10   999  $250 Million to under $500 Million
#
#                                        QJ
# 0  Information technology (IT) / software
# 1                                 Banking
# 2  Information technology (IT) / software
# 3  Information technology (IT) / software
# 4                                 Banking

# %%
df.tail()
# Out:
#      GENDER  AGE         EMPLOYMENT          STATE     REGION  \
# 595  Female   58  \tWork full-time      California       West
# 596  Female   58  \tWork full-time      Washington       West
# 597  Female   58  \tWork full-time        New York  Northeast
# 598  Female   55  \tWork full-time   Massachusetts  Northeast
# 599    Male   43  \tWork full-time      Washington       West
#
#                             EDUCATION  \
# 595               \tBachelor’s degree
# 596               \tBachelor’s degree
# 597  \tGraduate or post-graduate work
# 598               \tBachelor’s degree
# 599  \tGraduate or post-graduate work
#
#                                                  QA_M1  \
# 595  Maintain the distributed systems that execute ...
# 596  Develop, maintain, and optimize data systems t...
# 597                              Create data pipelines
# 598  Maintain the distributed systems that execute ...
# 599  Develop, maintain, and optimize data systems t...
#
#                                                  QA_M2  \
# 595                      Put analytics into production
# 596  Write tests to ensure that bad data is detecte...
# 597  Ensure that the data architecture will scale a...
# 598              Maintain data in ready-to-use formats
# 599  Manage continuous integration and continuous d...
#
#                                                  QA_M3  \
# 595  Develop, maintain, and optimize data systems t...
# 596                                Write and test code
# 597                      Put analytics into production
# 598  Develop, maintain, and optimize data systems t...
# 599              Maintain data in ready-to-use formats
#
#                                                  QA_M4  \
# 595                              Create data pipelines
# 596              Maintain data in ready-to-use formats
# 597  Develop, maintain, and optimize data systems t...
# 598  Write tests to ensure that bad data is detecte...
# 599                                                NaN
#
#                                                  QA_M5  \
# 595              Maintain data in ready-to-use formats
# 596  Maintain the distributed systems that execute ...
# 597  Maintain the distributed systems that execute ...
# 598                                Write and test code
# 599                                                NaN
#
#                                                  QA_M6 QA_M7 QA_M8  \
# 595  Write tests to ensure that bad data is detecte...   NaN   NaN
# 596  Manage continuous integration and continuous d...   NaN   NaN
# 597                                Write and test code   NaN   NaN
# 598                              Create data pipelines   NaN   NaN
# 599                                                NaN   NaN   NaN
#
#                        QB   QC  \
# 595  Enterprise Architect   No
# 596         Data Engineer   No
# 597         Data Engineer   No
# 598         Data Engineer   No
# 599  Data Management Lead  Yes
#
#                                                     QD  \
# 595  We have not implemented DataOps into our proce...
# 596  We have partially implemented DataOps into our...
# 597  We have not implemented DataOps into our proce...
# 598  We have not implemented DataOps into our proce...
# 599  We have mostly or fully implemented DataOps in...
#
#                                                     Q1            Q2   Q3  \
# 595                  We are confident they won’t break         Often   10
# 596                  We are confident they won’t break         Often   15
# 597  We frequently hope and pray that things don’t ...         Often   25
# 598  We frequently hope and pray that things don’t ...         Often   10
# 599  We frequently hope and pray that things don’t ...  All the time  100
#
#       Q4                                              Q5_M1  \
# 595   10            Fast pace of requests from stakeholders
# 596   10  Constantly playing catch up with stakeholder r...
# 597   15            Fast pace of requests from stakeholders
# 598   15            Fast pace of requests from stakeholders
# 599  100            Unreasonable requests from stakeholders
#
#                                                  Q5_M2  \
# 595  Focusing too much on maintaining data pipeline...
# 596  Focusing too much on maintaining data pipeline...
# 597         Lack of feedback on the products delivered
# 598  Constantly playing catch up with stakeholder r...
# 599                                                NaN
#
#                                                  Q5_M3 Q5_M4 Q5_M5  \
# 595  Focusing too much time on finding and fixing e...   NaN   NaN
# 596            Unreasonable requests from stakeholders   NaN   NaN
# 597  Constantly playing catch up with stakeholder r...   NaN   NaN
# 598         Lack of feedback on the products delivered   NaN   NaN
# 599                                                NaN   NaN   NaN
#
#                  Q6     Q7            Q8               Q9  \
# 595  Agree somewhat  Often         Often  Somewhat likely
# 596  Agree somewhat  Often     Sometimes  Somewhat likely
# 597  Agree somewhat  Often     Sometimes      Very likely
# 598  Agree somewhat  Often         Often  Somewhat likely
# 599  Agree strongly  Often  All the time      Very likely
#
#                      Q10                   Q11                   Q12  \
# 595  Yes, multiple times    Somewhat difficult  Somewhat effectively
# 596  Yes, multiple times    Somewhat difficult  Somewhat effectively
# 597  Yes, multiple times    Somewhat difficult  Somewhat effectively
# 598  Yes, multiple times    Somewhat difficult  Somewhat effectively
# 599  Yes, multiple times  Not at all difficult  Not very effectively
#
#                     Q13                                             Q14_M1  \
# 595      Very important  We haven't budgeted or don't have the budget f...
# 596  Somewhat important  Difficulty communicating or engaging with othe...
# 597  Somewhat important                     Too busy to make it a priority
# 598      Very important  We haven't budgeted or don't have the budget f...
# 599           Essential                                                NaN
#
#                                                 Q14_M2  \
# 595                     Too busy to make it a priority
# 596  Lack of buy-in from company leadership or othe...
# 597      Organization isn’t sure how to implement this
# 598        Scale of incorporating DataOps is too large
# 599                                                NaN
#
#                                                 Q14_M3  \
# 595           Lack of the right skills among employees
# 596      Organization isn’t sure how to implement this
# 597  We haven't budgeted or don't have the budget f...
# 598           Lack of knowledge around what DataOps is
# 599                                                NaN
#
#                                        Q14_M4 Q14_M5             Q15  QE  QF  \
# 595                                       NaN    NaN  Agree somewhat  20  10
# 596                                       NaN    NaN  Agree somewhat  18  10
# 597  Lack of knowledge around what DataOps is    NaN  Agree somewhat  18  10
# 598                                       NaN    NaN  Agree somewhat  16  10
# 599                                       NaN    NaN  Agree strongly   5   5
#
#      QG    QH                                  QI  \
# 595  59  3400  $250 Million to under $500 Million
# 596  50   650   $50 Million to under $100 Million
# 597  28   400    $25 Million to under $50 Million
# 598  27  1500  $100 Million to under $250 Million
# 599   5  1000  $250 Million to under $500 Million
#
#                                          QJ
# 595                                  Energy
# 596                              Consulting
# 597                                  Retail
# 598                              Accounting
# 599  Information technology (IT) / software

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## 1- removing symbols

# %%
df_obj = df.select_dtypes(['object'])
df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

# %%
df.head()
# Out:
#   GENDER  AGE      EMPLOYMENT      STATE   REGION  \
# 0   Male   39  Work full-time  Wisconsin  Midwest
# 1   Male   39  Work full-time    Florida    South
# 2   Male   34  Work full-time    Florida    South
# 3   Male   38  Work full-time  Wisconsin  Midwest
# 4   Male   39  Work full-time    Georgia    South
#
#                         EDUCATION  \
# 0  Graduate or post-graduate work
# 1               Bachelor’s degree
# 2  Graduate or post-graduate work
# 3  Graduate or post-graduate work
# 4  Graduate or post-graduate work
#
#                                                QA_M1  \
# 0  Maintain the distributed systems that execute ...
# 1  Develop, maintain, and optimize data systems t...
# 2                              Create data pipelines
# 3  Maintain the distributed systems that execute ...
# 4  Manage continuous integration and continuous d...
#
#                                                QA_M2  \
# 0  Develop, maintain, and optimize data systems t...
# 1  Maintain the distributed systems that execute ...
# 2  Develop, maintain, and optimize data systems t...
# 3              Maintain data in ready-to-use formats
# 4  Maintain the distributed systems that execute ...
#
#                                                QA_M3  \
# 0  Ensure that the data architecture will scale a...
# 1                                Write and test code
# 2  Write tests to ensure that bad data is detecte...
# 3  Manage continuous integration and continuous d...
# 4              Maintain data in ready-to-use formats
#
#                                                QA_M4  \
# 0                                Write and test code
# 1  Manage continuous integration and continuous d...
# 2  Maintain the distributed systems that execute ...
# 3                                                NaN
# 4  Develop, maintain, and optimize data systems t...
#
#                                                QA_M5  \
# 0  Manage continuous integration and continuous d...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Ensure that the data architecture will scale a...
#
#                            QA_M6  \
# 0  Put analytics into production
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#                                                QA_M7  \
# 0  Write tests to ensure that bad data is detecte...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                    QA_M8                         QB   QC  \
# 0  Maintain data in ready-to-use formats              ETL Developer  Yes
# 1                                    NaN       Enterprise Architect  Yes
# 2                                    NaN      Data & Analytics Lead  Yes
# 3                                    NaN  Enterprise Analytics Lead  Yes
# 4                                    NaN      Data & Analytics Lead  Yes
#
#                                                   QD  \
# 0  We have partially implemented DataOps into our...
# 1  We have partially implemented DataOps into our...
# 2  We have mostly or fully implemented DataOps in...
# 3  We have mostly or fully implemented DataOps in...
# 4  We have mostly or fully implemented DataOps in...
#
#                                                   Q1            Q2  Q3  Q4  \
# 0  We frequently hope and pray that things don’t ...         Often   1   1
# 1                  We are confident they won’t break     Sometimes  20  10
# 2  We frequently hope and pray that things don’t ...  All the time  25   5
# 3                  We are confident they won’t break  All the time  70  60
# 4                  We are confident they won’t break         Often  40  35
#
#                                                Q5_M1  \
# 0  Focusing too much on maintaining data pipeline...
# 1  Constantly playing catch up with stakeholder r...
# 2  Focusing too much time on finding and fixing e...
# 3            Fast pace of requests from stakeholders
# 4  Focusing too much on maintaining data pipeline...
#
#                                                Q5_M2  \
# 0                                                NaN
# 1                                                NaN
# 2            Unreasonable requests from stakeholders
# 3  Constantly playing catch up with stakeholder r...
# 4            Fast pace of requests from stakeholders
#
#                                                Q5_M3 Q5_M4 Q5_M5  \
# 0                                                NaN   NaN   NaN
# 1                                                NaN   NaN   NaN
# 2                                                NaN   NaN   NaN
# 3                                                NaN   NaN   NaN
# 4  Focusing too much time on finding and fixing e...   NaN   NaN
#
#                Q6            Q7            Q8                 Q9  \
# 0  Agree somewhat         Often         Often        Very likely
# 1  Agree strongly  All the time        Rarely        Very likely
# 2  Agree strongly     Sometimes  All the time    Not very likely
# 3  Agree strongly  All the time         Often  Not at all likely
# 4  Agree somewhat     Sometimes     Sometimes    Not very likely
#
#                    Q10                 Q11                   Q12  \
# 0  Yes, multiple times  Somewhat difficult  Somewhat effectively
# 1  Yes, multiple times  Somewhat difficult      Very effectively
# 2  Yes, multiple times  Somewhat difficult      Very effectively
# 3  Yes, multiple times      Very difficult      Very effectively
# 4            Yes, once  Somewhat difficult  Somewhat effectively
#
#               Q13                                         Q14_M1  \
# 0  Very important       Lack of knowledge around what DataOps is
# 1  Very important  Organization isn’t sure how to implement this
# 2       Essential                                            NaN
# 3       Essential                                            NaN
# 4  Very important                                            NaN
#
#                                               Q14_M2  \
# 0                                                NaN
# 1  Lack of buy-in from company leadership or othe...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      Q14_M3 Q14_M4 Q14_M5             Q15  QE  \
# 0                                       NaN    NaN    NaN  Agree somewhat  10
# 1  Lack of knowledge around what DataOps is    NaN    NaN  Agree somewhat   5
# 2                                       NaN    NaN    NaN  Agree strongly  10
# 3                                       NaN    NaN    NaN  Agree strongly  18
# 4                                       NaN    NaN    NaN  Agree somewhat   6
#
#    QF  QG    QH                                  QI  \
# 0  10  11  1500   $50 Million to under $100 Million
# 1  10  50  2000    $10 Million to under $25 Million
# 2  15  20    20                  $1 Billion or more
# 3  18  45   250  $100 Million to under $250 Million
# 4   7  10   999  $250 Million to under $500 Million
#
#                                        QJ
# 0  Information technology (IT) / software
# 1                                 Banking
# 2  Information technology (IT) / software
# 3  Information technology (IT) / software
# 4                                 Banking

# %% [markdown]
# ## 1- QA_M1 to QA_M8 repairing

# %%
df["QA_M1"].unique()
# Out:
# array(['Maintain the distributed systems that execute data pipelines',
#        'Develop, maintain, and optimize data systems to make data available for analysis',
#        'Create data pipelines',
#        'Manage continuous integration and continuous delivery/deployment (CI/CD) of new data products',
#        'Write and test code', 'Maintain data in ready-to-use formats',
#        'Ensure that the data architecture will scale appropriately',
#        'Write tests to ensure that bad data is detected and acted upon in production',
#        'Put analytics into production'], dtype=object)

# %%
pd.unique(df[["QA_M1","QA_M2", "QA_M3", "QA_M4", "QA_M5", "QA_M6", "QA_M7","QA_M8"]].values.ravel())
# Out:
# array(['Maintain the distributed systems that execute data pipelines',
#        'Develop, maintain, and optimize data systems to make data available for analysis',
#        'Ensure that the data architecture will scale appropriately',
#        'Write and test code',
#        'Manage continuous integration and continuous delivery/deployment (CI/CD) of new data products',
#        'Put analytics into production',
#        'Write tests to ensure that bad data is detected and acted upon in production',
#        'Maintain data in ready-to-use formats', nan,
#        'Create data pipelines'], dtype=object)

# %%
df.columns
# Out:
# Index(['GENDER', 'AGE', 'EMPLOYMENT', 'STATE', 'REGION', 'EDUCATION', 'QA_M1',
#        'QA_M2', 'QA_M3', 'QA_M4', 'QA_M5', 'QA_M6', 'QA_M7', 'QA_M8', 'QB',
#        'QC', 'QD', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5_M1', 'Q5_M2', 'Q5_M3', 'Q5_M4',
#        'Q5_M5', 'Q6', 'Q7', 'Q8', 'Q9', 'Q10', 'Q11', 'Q12', 'Q13', 'Q14_M1',
#        'Q14_M2', 'Q14_M3', 'Q14_M4', 'Q14_M5', 'Q15', 'QE', 'QF', 'QG', 'QH',
#        'QI', 'QJ'],
#       dtype='object')

# %%
ans = ['Maintain the distributed systems that execute data pipelines',
       'Ensure that the data architecture will scale appropriately',
       'Write and test code',
       'Manage continuous integration and continuous delivery/deployment (CI/CD) of new data products',
       'Put analytics into production',
       'Write tests to ensure that bad data is detected and acted upon in production',
       'Maintain data in ready-to-use formats',
       'Develop, maintain, and optimize data systems to make data available for analysis',
       'Create data pipelines']
for i in ans:
    name = {i[0:10].replace(" ", "_")}
    df[f"{name}"] = np.where((df["QA_M1"] == i) |
                             (df["QA_M2"] == i) |
                             (df["QA_M3"] == i) |
                             (df["QA_M4"] == i) |
                             (df["QA_M5"] == i) |
                             (df["QA_M6"] == i) |
                             (df["QA_M7"] == i) |
                             (df["QA_M8"] == i) , True, False)
df.head()
# Out:
#   GENDER  AGE      EMPLOYMENT      STATE   REGION  \
# 0   Male   39  Work full-time  Wisconsin  Midwest
# 1   Male   39  Work full-time    Florida    South
# 2   Male   34  Work full-time    Florida    South
# 3   Male   38  Work full-time  Wisconsin  Midwest
# 4   Male   39  Work full-time    Georgia    South
#
#                         EDUCATION  \
# 0  Graduate or post-graduate work
# 1               Bachelor’s degree
# 2  Graduate or post-graduate work
# 3  Graduate or post-graduate work
# 4  Graduate or post-graduate work
#
#                                                QA_M1  \
# 0  Maintain the distributed systems that execute ...
# 1  Develop, maintain, and optimize data systems t...
# 2                              Create data pipelines
# 3  Maintain the distributed systems that execute ...
# 4  Manage continuous integration and continuous d...
#
#                                                QA_M2  \
# 0  Develop, maintain, and optimize data systems t...
# 1  Maintain the distributed systems that execute ...
# 2  Develop, maintain, and optimize data systems t...
# 3              Maintain data in ready-to-use formats
# 4  Maintain the distributed systems that execute ...
#
#                                                QA_M3  \
# 0  Ensure that the data architecture will scale a...
# 1                                Write and test code
# 2  Write tests to ensure that bad data is detecte...
# 3  Manage continuous integration and continuous d...
# 4              Maintain data in ready-to-use formats
#
#                                                QA_M4  \
# 0                                Write and test code
# 1  Manage continuous integration and continuous d...
# 2  Maintain the distributed systems that execute ...
# 3                                                NaN
# 4  Develop, maintain, and optimize data systems t...
#
#                                                QA_M5  \
# 0  Manage continuous integration and continuous d...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Ensure that the data architecture will scale a...
#
#                            QA_M6  \
# 0  Put analytics into production
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#                                                QA_M7  \
# 0  Write tests to ensure that bad data is detecte...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                    QA_M8                         QB   QC  \
# 0  Maintain data in ready-to-use formats              ETL Developer  Yes
# 1                                    NaN       Enterprise Architect  Yes
# 2                                    NaN      Data & Analytics Lead  Yes
# 3                                    NaN  Enterprise Analytics Lead  Yes
# 4                                    NaN      Data & Analytics Lead  Yes
#
#                                                   QD  \
# 0  We have partially implemented DataOps into our...
# 1  We have partially implemented DataOps into our...
# 2  We have mostly or fully implemented DataOps in...
# 3  We have mostly or fully implemented DataOps in...
# 4  We have mostly or fully implemented DataOps in...
#
#                                                   Q1            Q2  Q3  Q4  \
# 0  We frequently hope and pray that things don’t ...         Often   1   1
# 1                  We are confident they won’t break     Sometimes  20  10
# 2  We frequently hope and pray that things don’t ...  All the time  25   5
# 3                  We are confident they won’t break  All the time  70  60
# 4                  We are confident they won’t break         Often  40  35
#
#                                                Q5_M1  \
# 0  Focusing too much on maintaining data pipeline...
# 1  Constantly playing catch up with stakeholder r...
# 2  Focusing too much time on finding and fixing e...
# 3            Fast pace of requests from stakeholders
# 4  Focusing too much on maintaining data pipeline...
#
#                                                Q5_M2  \
# 0                                                NaN
# 1                                                NaN
# 2            Unreasonable requests from stakeholders
# 3  Constantly playing catch up with stakeholder r...
# 4            Fast pace of requests from stakeholders
#
#                                                Q5_M3 Q5_M4 Q5_M5  \
# 0                                                NaN   NaN   NaN
# 1                                                NaN   NaN   NaN
# 2                                                NaN   NaN   NaN
# 3                                                NaN   NaN   NaN
# 4  Focusing too much time on finding and fixing e...   NaN   NaN
#
#                Q6            Q7            Q8                 Q9  \
# 0  Agree somewhat         Often         Often        Very likely
# 1  Agree strongly  All the time        Rarely        Very likely
# 2  Agree strongly     Sometimes  All the time    Not very likely
# 3  Agree strongly  All the time         Often  Not at all likely
# 4  Agree somewhat     Sometimes     Sometimes    Not very likely
#
#                    Q10                 Q11                   Q12  \
# 0  Yes, multiple times  Somewhat difficult  Somewhat effectively
# 1  Yes, multiple times  Somewhat difficult      Very effectively
# 2  Yes, multiple times  Somewhat difficult      Very effectively
# 3  Yes, multiple times      Very difficult      Very effectively
# 4            Yes, once  Somewhat difficult  Somewhat effectively
#
#               Q13                                         Q14_M1  \
# 0  Very important       Lack of knowledge around what DataOps is
# 1  Very important  Organization isn’t sure how to implement this
# 2       Essential                                            NaN
# 3       Essential                                            NaN
# 4  Very important                                            NaN
#
#                                               Q14_M2  \
# 0                                                NaN
# 1  Lack of buy-in from company leadership or othe...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                      Q14_M3 Q14_M4 Q14_M5             Q15  QE  \
# 0                                       NaN    NaN    NaN  Agree somewhat  10
# 1  Lack of knowledge around what DataOps is    NaN    NaN  Agree somewhat   5
# 2                                       NaN    NaN    NaN  Agree strongly  10
# 3                                       NaN    NaN    NaN  Agree strongly  18
# 4                                       NaN    NaN    NaN  Agree somewhat   6
#
#    QF  QG    QH                                  QI  \
# 0  10  11  1500   $50 Million to under $100 Million
# 1  10  50  2000    $10 Million to under $25 Million
# 2  15  20    20                  $1 Billion or more
# 3  18  45   250  $100 Million to under $250 Million
# 4   7  10   999  $250 Million to under $500 Million
#
#                                        QJ  {'Maintain_t'}  {'Ensure_tha'}  \
# 0  Information technology (IT) / software            True            True
# 1                                 Banking            True           False
# 2  Information technology (IT) / software            True           False
# 3  Information technology (IT) / software            True           False
# 4                                 Banking            True            True
#
#    {'Write_and_'}  {'Manage_con'}  {'Put_analyt'}  {'Write_test'}  \
# 0            True            True            True            True
# 1            True            True           False           False
# 2           False           False           False            True
# 3           False            True           False           False
# 4           False            True           False           False
#
#    {'Maintain_d'}  {'Develop,_m'}  {'Create_dat'}
# 0            True            True           False
# 1           False            True           False
# 2           False            True            True
# 3            True           False           False
# 4            True            True           False

# %%
df2 = df.drop(['QA_M1','QA_M2', 'QA_M3', 'QA_M4', 'QA_M5', 'QA_M6', 'QA_M7', 'QA_M8'], axis=1)
df2
# Out:
#      GENDER  AGE      EMPLOYMENT          STATE     REGION  \
# 0      Male   39  Work full-time      Wisconsin    Midwest
# 1      Male   39  Work full-time        Florida      South
# 2      Male   34  Work full-time        Florida      South
# 3      Male   38  Work full-time      Wisconsin    Midwest
# 4      Male   39  Work full-time        Georgia      South
# ..      ...  ...             ...            ...        ...
# 595  Female   58  Work full-time     California       West
# 596  Female   58  Work full-time     Washington       West
# 597  Female   58  Work full-time       New York  Northeast
# 598  Female   55  Work full-time  Massachusetts  Northeast
# 599    Male   43  Work full-time     Washington       West
#
#                           EDUCATION                         QB   QC  \
# 0    Graduate or post-graduate work              ETL Developer  Yes
# 1                 Bachelor’s degree       Enterprise Architect  Yes
# 2    Graduate or post-graduate work      Data & Analytics Lead  Yes
# 3    Graduate or post-graduate work  Enterprise Analytics Lead  Yes
# 4    Graduate or post-graduate work      Data & Analytics Lead  Yes
# ..                              ...                        ...  ...
# 595               Bachelor’s degree       Enterprise Architect   No
# 596               Bachelor’s degree              Data Engineer   No
# 597  Graduate or post-graduate work              Data Engineer   No
# 598               Bachelor’s degree              Data Engineer   No
# 599  Graduate or post-graduate work       Data Management Lead  Yes
#
#                                                     QD  \
# 0    We have partially implemented DataOps into our...
# 1    We have partially implemented DataOps into our...
# 2    We have mostly or fully implemented DataOps in...
# 3    We have mostly or fully implemented DataOps in...
# 4    We have mostly or fully implemented DataOps in...
# ..                                                 ...
# 595  We have not implemented DataOps into our proce...
# 596  We have partially implemented DataOps into our...
# 597  We have not implemented DataOps into our proce...
# 598  We have not implemented DataOps into our proce...
# 599  We have mostly or fully implemented DataOps in...
#
#                                                     Q1            Q2   Q3  \
# 0    We frequently hope and pray that things don’t ...         Often    1
# 1                    We are confident they won’t break     Sometimes   20
# 2    We frequently hope and pray that things don’t ...  All the time   25
# 3                    We are confident they won’t break  All the time   70
# 4                    We are confident they won’t break         Often   40
# ..                                                 ...           ...  ...
# 595                  We are confident they won’t break         Often   10
# 596                  We are confident they won’t break         Often   15
# 597  We frequently hope and pray that things don’t ...         Often   25
# 598  We frequently hope and pray that things don’t ...         Often   10
# 599  We frequently hope and pray that things don’t ...  All the time  100
#
#       Q4                                              Q5_M1  \
# 0      1  Focusing too much on maintaining data pipeline...
# 1     10  Constantly playing catch up with stakeholder r...
# 2      5  Focusing too much time on finding and fixing e...
# 3     60            Fast pace of requests from stakeholders
# 4     35  Focusing too much on maintaining data pipeline...
# ..   ...                                                ...
# 595   10            Fast pace of requests from stakeholders
# 596   10  Constantly playing catch up with stakeholder r...
# 597   15            Fast pace of requests from stakeholders
# 598   15            Fast pace of requests from stakeholders
# 599  100            Unreasonable requests from stakeholders
#
#                                                  Q5_M2  \
# 0                                                  NaN
# 1                                                  NaN
# 2              Unreasonable requests from stakeholders
# 3    Constantly playing catch up with stakeholder r...
# 4              Fast pace of requests from stakeholders
# ..                                                 ...
# 595  Focusing too much on maintaining data pipeline...
# 596  Focusing too much on maintaining data pipeline...
# 597         Lack of feedback on the products delivered
# 598  Constantly playing catch up with stakeholder r...
# 599                                                NaN
#
#                                                  Q5_M3 Q5_M4 Q5_M5  \
# 0                                                  NaN   NaN   NaN
# 1                                                  NaN   NaN   NaN
# 2                                                  NaN   NaN   NaN
# 3                                                  NaN   NaN   NaN
# 4    Focusing too much time on finding and fixing e...   NaN   NaN
# ..                                                 ...   ...   ...
# 595  Focusing too much time on finding and fixing e...   NaN   NaN
# 596            Unreasonable requests from stakeholders   NaN   NaN
# 597  Constantly playing catch up with stakeholder r...   NaN   NaN
# 598         Lack of feedback on the products delivered   NaN   NaN
# 599                                                NaN   NaN   NaN
#
#                  Q6            Q7            Q8                 Q9  \
# 0    Agree somewhat         Often         Often        Very likely
# 1    Agree strongly  All the time        Rarely        Very likely
# 2    Agree strongly     Sometimes  All the time    Not very likely
# 3    Agree strongly  All the time         Often  Not at all likely
# 4    Agree somewhat     Sometimes     Sometimes    Not very likely
# ..              ...           ...           ...                ...
# 595  Agree somewhat         Often         Often    Somewhat likely
# 596  Agree somewhat         Often     Sometimes    Somewhat likely
# 597  Agree somewhat         Often     Sometimes        Very likely
# 598  Agree somewhat         Often         Often    Somewhat likely
# 599  Agree strongly         Often  All the time        Very likely
#
#                      Q10                   Q11                   Q12  \
# 0    Yes, multiple times    Somewhat difficult  Somewhat effectively
# 1    Yes, multiple times    Somewhat difficult      Very effectively
# 2    Yes, multiple times    Somewhat difficult      Very effectively
# 3    Yes, multiple times        Very difficult      Very effectively
# 4              Yes, once    Somewhat difficult  Somewhat effectively
# ..                   ...                   ...                   ...
# 595  Yes, multiple times    Somewhat difficult  Somewhat effectively
# 596  Yes, multiple times    Somewhat difficult  Somewhat effectively
# 597  Yes, multiple times    Somewhat difficult  Somewhat effectively
# 598  Yes, multiple times    Somewhat difficult  Somewhat effectively
# 599  Yes, multiple times  Not at all difficult  Not very effectively
#
#                     Q13                                             Q14_M1  \
# 0        Very important           Lack of knowledge around what DataOps is
# 1        Very important      Organization isn’t sure how to implement this
# 2             Essential                                                NaN
# 3             Essential                                                NaN
# 4        Very important                                                NaN
# ..                  ...                                                ...
# 595      Very important  We haven't budgeted or don't have the budget f...
# 596  Somewhat important  Difficulty communicating or engaging with othe...
# 597  Somewhat important                     Too busy to make it a priority
# 598      Very important  We haven't budgeted or don't have the budget f...
# 599           Essential                                                NaN
#
#                                                 Q14_M2  \
# 0                                                  NaN
# 1    Lack of buy-in from company leadership or othe...
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 595                     Too busy to make it a priority
# 596  Lack of buy-in from company leadership or othe...
# 597      Organization isn’t sure how to implement this
# 598        Scale of incorporating DataOps is too large
# 599                                                NaN
#
#                                                 Q14_M3  \
# 0                                                  NaN
# 1             Lack of knowledge around what DataOps is
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 595           Lack of the right skills among employees
# 596      Organization isn’t sure how to implement this
# 597  We haven't budgeted or don't have the budget f...
# 598           Lack of knowledge around what DataOps is
# 599                                                NaN
#
#                                        Q14_M4 Q14_M5             Q15  QE  QF  \
# 0                                         NaN    NaN  Agree somewhat  10  10
# 1                                         NaN    NaN  Agree somewhat   5  10
# 2                                         NaN    NaN  Agree strongly  10  15
# 3                                         NaN    NaN  Agree strongly  18  18
# 4                                         NaN    NaN  Agree somewhat   6   7
# ..                                        ...    ...             ...  ..  ..
# 595                                       NaN    NaN  Agree somewhat  20  10
# 596                                       NaN    NaN  Agree somewhat  18  10
# 597  Lack of knowledge around what DataOps is    NaN  Agree somewhat  18  10
# 598                                       NaN    NaN  Agree somewhat  16  10
# 599                                       NaN    NaN  Agree strongly   5   5
#
#      QG    QH                                  QI  \
# 0    11  1500   $50 Million to under $100 Million
# 1    50  2000    $10 Million to under $25 Million
# 2    20    20                  $1 Billion or more
# 3    45   250  $100 Million to under $250 Million
# 4    10   999  $250 Million to under $500 Million
# ..   ..   ...                                 ...
# 595  59  3400  $250 Million to under $500 Million
# 596  50   650   $50 Million to under $100 Million
# 597  28   400    $25 Million to under $50 Million
# 598  27  1500  $100 Million to under $250 Million
# 599   5  1000  $250 Million to under $500 Million
#
#                                          QJ  {'Maintain_t'}  {'Ensure_tha'}  \
# 0    Information technology (IT) / software            True            True
# 1                                   Banking            True           False
# 2    Information technology (IT) / software            True           False
# 3    Information technology (IT) / software            True           False
# 4                                   Banking            True            True
# ..                                      ...             ...             ...
# 595                                  Energy            True           False
# 596                              Consulting            True           False
# 597                                  Retail            True            True
# 598                              Accounting            True           False
# 599  Information technology (IT) / software           False           False
#
#      {'Write_and_'}  {'Manage_con'}  {'Put_analyt'}  {'Write_test'}  \
# 0              True            True            True            True
# 1              True            True           False           False
# 2             False           False           False            True
# 3             False            True           False           False
# 4             False            True           False           False
# ..              ...             ...             ...             ...
# 595           False           False            True            True
# 596            True            True           False            True
# 597            True           False            True           False
# 598            True           False           False            True
# 599           False            True           False           False
#
#      {'Maintain_d'}  {'Develop,_m'}  {'Create_dat'}
# 0              True            True           False
# 1             False            True           False
# 2             False            True            True
# 3              True           False           False
# 4              True            True           False
# ..              ...             ...             ...
# 595            True            True            True
# 596            True            True           False
# 597           False            True            True
# 598            True            True            True
# 599            True            True           False
#
# [600 rows x 47 columns]

# %%
df2.shape
# Out:
# (600, 47)

# %%
df.shape
# Out:
# (600, 55)
